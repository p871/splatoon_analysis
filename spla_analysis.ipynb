# %%
import pandas as pd
import numpy as np
pd.options.display.max_rows = 100

# %%
def get_95confidence_interval(win_rate, n, upper=False):
    win_count = n-round(n*win_rate)
    var = np.var([1 for _ in range(win_count)] + [0 for _ in range(n-win_count)], ddof=1)
    if upper == True:
        return  win_rate +1.96*np.sqrt((var/n))
    return win_rate -1.96*np.sqrt((var/n))

# %%
usecols = ['id', 'mode', 'stage',
       'A1-weapon', 'A1-rank', 'A2-weapon', 'A2-rank',
       'A3-weapon', 'A3-rank', 'A4-weapon', 'A4-rank',
       'B1-weapon', 'B1-rank', 'B2-weapon', 'B2-rank',
       'B3-weapon', 'B3-rank', 'B4-weapon', 'B4-rank',
       'y']
drop_list = ['A1-rank','A2-rank','A3-rank','A4-rank','B1-rank','B2-rank','B3-rank','B4-rank','mode']
weapon_list = ['A1-weapon', 'A2-weapon', 'A3-weapon', 'A4-weapon', 'B1-weapon', 'B2-weapon', 'B3-weapon', 'B4-weapon']
col_list = ['stage', 'weapon', 'win_rate', 'count']
feb_stage_list = ['gangaze', 'kombu', 'hakofugu', 'tachiuo', 'mongara', 'mozuku', 'engawa', 'anchovy']
mar_stage_list = ['battera', 'chouzame', 'fujitsubo', 'hokke', 'bbass', 'zatou', 'shottsuru', 'mutsugoro']

# %%
df = pd.read_csv('train_data.csv', usecols=usecols)

# %%
# 1年以上前のデータではあるが、2021/02現在のgame-verが 5.3.1/5.4.0 であり、大幅な update が行われていないので使ってみる
pd.read_csv('train_data.csv').head()
# Out:
#    id                     period game-ver lobby-mode     lobby      mode  \
# 0   1  2019-10-15T20:00:00+00:00    5.0.1    regular  standard  nawabari
# 1   2  2019-12-14T04:00:00+00:00    5.0.1    regular  standard  nawabari
# 2   3  2019-12-25T14:00:00+00:00    5.0.1      gachi  standard      hoko
# 3   4  2019-11-11T14:00:00+00:00    5.0.1    regular  standard  nawabari
# 4   5  2019-12-14T06:00:00+00:00    5.0.1      gachi  standard      hoko
#
#      stage            A1-weapon A1-rank  A1-level  ...       B2-weapon  \
# 0  sumeshi      sshooter_becchu     NaN       139  ...  hokusai_becchu
# 1  arowana  parashelter_sorella     NaN       198  ...     squiclean_b
# 2      ama               nzap89      a-       114  ...          nzap85
# 3   engawa          bamboo14mk1     NaN       336  ...         liter4k
# 4  chozame               bold_7       x       299  ...    sputtery_hue
#
#   B2-rank  B2-level            B3-weapon B3-rank  B3-level  \
# 0     NaN      26.0  herocharger_replica     NaN      68.0
# 1     NaN     118.0       campingshelter     NaN     168.0
# 2      a+     163.0         prime_becchu      a-     160.0
# 3     NaN     189.0        promodeler_mg     NaN     194.0
# 4       x      45.0   bucketslosher_soda       x     246.0
#
#             B4-weapon B4-rank  B4-level  y
# 0           sharp_neo     NaN      31.0  1
# 1      sputtery_clear     NaN     151.0  0
# 2  dualsweeper_custom       a     126.0  0
# 3   hotblaster_custom     NaN     391.0  0
# 4              wakaba       x     160.0  1
#
# [5 rows x 32 columns]

# %%
df.head()
# Out:
#    id      mode    stage            A1-weapon A1-rank           A2-weapon  \
# 0   1  nawabari  sumeshi      sshooter_becchu     NaN     soytuber_custom
# 1   2  nawabari  arowana  parashelter_sorella     NaN          jetsweeper
# 2   3      hoko      ama               nzap89      a-    quadhopper_black
# 3   4  nawabari   engawa          bamboo14mk1     NaN  splatroller_becchu
# 4   5      hoko  chozame               bold_7       x          hissen_hue
#
#   A2-rank            A3-weapon A3-rank     A4-weapon A4-rank  \
# 0     NaN            pablo_hue     NaN       hokusai     NaN
# 1     NaN  campingshelter_camo     NaN        nzap85     NaN
# 2       a         prime_becchu       a    jetsweeper       a
# 3     NaN         dynamo_tesla     NaN  prime_becchu     NaN
# 4       x          h3reelgun_d       x   splatroller       x
#
#              B1-weapon B1-rank       B2-weapon B2-rank            B3-weapon  \
# 0               bold_7     NaN  hokusai_becchu     NaN  herocharger_replica
# 1               momiji     NaN     squiclean_b     NaN       campingshelter
# 2               bold_7      a-          nzap85      a+         prime_becchu
# 3  splatcharger_becchu     NaN         liter4k     NaN        promodeler_mg
# 4                 furo       x    sputtery_hue       x   bucketslosher_soda
#
#   B3-rank           B4-weapon B4-rank  y
# 0     NaN           sharp_neo     NaN  1
# 1     NaN      sputtery_clear     NaN  0
# 2      a-  dualsweeper_custom       a  0
# 3     NaN   hotblaster_custom     NaN  0
# 4       x              wakaba       x  1

# %%
df_area = df[df['mode']=='area']

# %%
def eliminate_duplicates(_df):
    for x in range(len(_df)):
        for i in range(4):
            for j in range(4):
                item = _df.iloc[x, i+3]
                if item == _df.iloc[x,j+7]:
                    _df.iloc[x,i+3] = np.nan
                    _df.iloc[x,j+7] = np.nan
                    break
    return _df

# %%
def modify_result(_df):
    _df = pd.melt(_df, id_vars=['id', 'stage', 'y'], value_vars=weapon_list, value_name='weapon').drop('variable', axis=1)
    _df.iloc[len(_df)//2:, 2] = _df.iloc[len(_df)//2:, 2].apply(lambda x : 1-x)
    return _df

# %%
df_area_a = df_area[df_area['A1-rank'].str.contains('a')].drop(drop_list, axis=1).reset_index(drop=True)
df_area_s = df_area[df_area['A1-rank'] == 's'].drop(drop_list, axis=1).reset_index(drop=True)
df_area_sp = df_area[df_area['A1-rank'] == 's+'].drop(drop_list, axis=1).reset_index(drop=True)
df_area_x = df_area[df_area['A1-rank'] == 'x'].drop(drop_list, axis=1).reset_index(drop=True)
df_area_asp = df_area[df_area['A1-rank'].str.contains('a|s')].drop(drop_list, axis=1).reset_index(drop=True)
df_area_ssp = df_area[df_area['A1-rank'].str.contains('s')].drop(drop_list, axis=1).reset_index(drop=True)
df_area_aspx = df_area[df_area['A1-rank'].str.contains('a|s|x')].drop(drop_list, axis=1).reset_index(drop=True)

# %%
df_area_a = eliminate_duplicates(df_area_a)
df_area_s = eliminate_duplicates(df_area_s)
df_area_sp = eliminate_duplicates(df_area_sp)
df_area_x = eliminate_duplicates(df_area_x)
df_area_asp = eliminate_duplicates(df_area_asp)
df_area_ssp = eliminate_duplicates(df_area_ssp)
df_area_aspx = eliminate_duplicates(df_area_aspx)

# %%
df_a = modify_result(df_area_a)
df_s = modify_result(df_area_s)
df_sp = modify_result(df_area_sp)
df_x = modify_result(df_area_x)
df_asp = modify_result(df_area_asp)
df_ssp = modify_result(df_area_ssp)
df_aspx = modify_result(df_area_aspx)

# %%
df_area_a = df_a.groupby(['stage','weapon']).agg({'y':'mean', 'id':'count'}).reset_index().sort_values('id', ascending=False)
df_area_s = df_s.groupby(['stage','weapon']).agg({'y':'mean', 'id':'count'}).reset_index().sort_values('id', ascending=False)
df_area_sp = df_sp.groupby(['stage','weapon']).agg({'y':'mean', 'id':'count'}).reset_index().sort_values('id', ascending=False)
df_area_x = df_x.groupby(['stage','weapon']).agg({'y':'mean', 'id':'count'}).reset_index().sort_values('id', ascending=False)
df_area_asp = df_asp.groupby(['stage','weapon']).agg({'y':'mean', 'id':'count'}).reset_index().sort_values('id', ascending=False)
df_area_ssp = df_ssp.groupby(['stage','weapon']).agg({'y':'mean', 'id':'count'}).reset_index().sort_values('id', ascending=False)
df_area_aspx = df_ssp.groupby(['stage','weapon']).agg({'y':'mean', 'id':'count'}).reset_index().sort_values('id', ascending=False)
df_area_a.columns = ['stage', 'weapon', 'a_win_rate', 'a_count']
df_area_s.columns = ['stage', 'weapon', 's_win_rate', 's_count']
df_area_sp.columns = ['stage', 'weapon', 'sp_win_rate', 'sp_count']
df_area_x.columns = ['stage', 'weapon', 'x_win_rate', 'x_count']
df_area_asp.columns = ['stage', 'weapon', 'win_rate', 'count']
df_area_ssp.columns = ['stage', 'weapon', 'win_rate', 'count']
df_area_aspx.columns = ['stage', 'weapon', 'win_rate', 'count']

# %%
df_feb = df_asp[df_asp['stage'].isin(feb_stage_list)].groupby('weapon').agg({'y':'mean', 'id':'count'}).reset_index().sort_values('id', ascending=False)
df_feb['min95'] = [get_95confidence_interval(i, j, False) for i, j  in zip(df_feb['y'], df_feb['id'])]

# %%
df_mar = df_asp[df_asp['stage'].isin(mar_stage_list)].groupby('weapon').agg({'y':'mean', 'id':'count'}).reset_index().sort_values('id', ascending=False)
df_mar['min95'] = [get_95confidence_interval(i, j, False) for i, j  in zip(df_mar['y'], df_mar['id'])]

# %%
df_mar.sort_values('min95', ascending=False)
# Out:
#                      weapon         y   id     min95
# 93             prime_becchu  0.573566  802  0.539338
# 7               bamboo14mk3  0.750000   16  0.537824
# 12                   bold_7  0.598802  167  0.524463
# 19           campingshelter  0.705882   17  0.489282
# 32         explosher_custom  0.593023   86  0.489192
# 106     screwslosher_becchu  0.570370  135  0.486865
# 11                     bold  0.530973  339  0.477849
# 42       heroroller_replica  0.542056  214  0.475302
# 76                   momiji  0.532423  293  0.475291
# 97            promodeler_rg  0.636364   33  0.472235
# 29            dynamo_becchu  0.540000  200  0.470926
# 115             splatroller  0.515991  469  0.470762
# 137     variableroller_foil  0.562500  112  0.470625
# 98         quadhopper_black  0.562500  112  0.470625
# 26              dualsweeper  0.549669  151  0.470312
# 83                   nzap85  0.502075  723  0.465628
# 27       dualsweeper_custom  0.500785  637  0.461956
# 56               jetsweeper  0.529412  204  0.460917
# 125          sputtery_clear  0.513678  329  0.459669
# 62       kugelschreiber_hue  0.537415  147  0.456813
# 134         sshooter_becchu  0.518519  216  0.451884
# 4                96gal_deco  0.578947   57  0.450771
# 2                52gal_deco  0.750000    8  0.449938
# 28                   dynamo  0.800000    5  0.449385
# 55             hydra_custom  0.516432  213  0.449320
# 75         maneuver_collabo  0.554217   83  0.447282
# 48               hissen_hue  0.536364  110  0.443172
# 84                   nzap89  0.486869  495  0.442836
# 10      barrelspinner_remix  0.500000  250  0.438019
# 44      heroshooter_replica  0.589744   39  0.435366
# 34                furo_deco  0.512821  156  0.434384
# 49                  hokusai  0.553846   65  0.432999
# 138                  wakaba  0.469352  571  0.428417
# 50           hokusai_becchu  0.510638  141  0.428126
# 95            promodeler_mg  0.503650  137  0.419925
# 66                  liter4k  0.503759  133  0.418785
# 86      octoshooter_replica  0.537313   67  0.417921
# 85                   ochiba  0.496296  135  0.411954
# 136          variableroller  0.600000   25  0.407960
# 82                   nzap83  0.495726  117  0.405129
# 109               sharp_neo  0.471795  195  0.401727
# 25         clashblaster_neo  0.491525  118  0.401322
# 135        sshooter_collabo  0.474286  175  0.400303
# 91      parashelter_sorella  0.526316   57  0.396692
# 65              l3reelgun_d  0.486726  113  0.394568
# 63                l3reelgun  0.494737   95  0.394197
# 88                pablo_hue  0.529412   51  0.392422
# 74          maneuver_becchu  0.482456  114  0.390727
# 87                    pablo  0.476190  126  0.388984
# 72        longblaster_necro  0.507463   67  0.387750
# ..                      ...       ...  ...       ...
# 113     splatcharger_becchu  0.426667   75  0.314730
# 107        screwslosher_neo  0.571429   14  0.312199
# 1              52gal_becchu  0.415584   77  0.305506
# 9        barrelspinner_deco  0.446809   47  0.304672
# 78               nautilus79  0.526316   19  0.301800
# 8             barrelspinner  0.500000   24  0.299958
# 52               hotblaster  0.468750   32  0.295848
# 70              longblaster  0.450000   40  0.295825
# 47                   hissen  0.450000   40  0.295825
# 112            splatcharger  0.386792  106  0.294078
# 18       bucketslosher_soda  0.435897   39  0.280267
# 22                   carbon  0.428571   42  0.278905
# 54                    hydra  0.422222   45  0.277911
# 57        jetsweeper_custom  0.432432   37  0.272799
# 122     splatspinner_becchu  0.500000   18  0.269012
# 6               bamboo14mk2  0.538462   13  0.267464
# 108                   sharp  0.424242   33  0.255616
# 99         quadhopper_white  0.500000   16  0.255000
# 46      herospinner_replica  0.500000   14  0.238084
# 130             squiclean_a  0.400000   35  0.237697
# 103             rapid_elite  0.400000   30  0.224692
# 17       bucketslosher_deco  0.407407   27  0.222068
# 0                     52gal  0.428571   21  0.216911
# 128        spygadget_becchu  0.387097   31  0.215630
# 104        rapid_elite_deco  0.571429    7  0.204823
# 16            bucketslosher  0.421053   19  0.199045
# 92                    prime  0.312500   64  0.198939
# 37              h3reelgun_d  0.351351   37  0.197525
# 89          pablo_permanent  0.461538   13  0.190541
# 36         h3reelgun_cherry  0.500000   10  0.190097
# 69     liter4k_scope_custom  0.500000   10  0.190097
# 123    splatspinner_collabo  0.380952   21  0.173249
# 21   campingshelter_sorella  0.454545   11  0.160288
# 38      heroblaster_replica  0.500000    8  0.153518
# 100                   rapid  0.350000   20  0.140959
# 67           liter4k_custom  0.318182   22  0.123549
# 58                kelvin525  0.384615   13  0.120149
# 110                soytuber  0.444444    9  0.119801
# 39        herobrush_replica  0.500000    6  0.099917
# 81                 nova_neo  0.500000    6  0.099917
# 71       longblaster_custom  0.500000    6  0.099917
# 53        hotblaster_custom  0.285714   21  0.092496
# 35                h3reelgun  0.363636   11  0.079357
# 90              parashelter  0.294118   17  0.077518
# 105            screwslosher  0.375000    8  0.039520
# 24             clashblaster  0.230769   13  0.001734
# 64         l3reelgun_becchu  0.200000   10 -0.047923
# 111         soytuber_custom  0.285714    7 -0.048950
# 45      heroslosher_replica  0.200000    5 -0.150615
# 14             bottlegeyser  0.500000    2 -0.192965
#
# [139 rows x 4 columns]

# %%
df_ssp[df_ssp['stage'].isin(mar_stage_list)].groupby('weapon').agg({'y':'mean', 'id':'count'}).reset_index().sort_values('id', ascending=False)
# Out:
#                      weapon         y   id
# 93             prime_becchu  0.565079  630
# 83                   nzap85  0.493266  594
# 27       dualsweeper_custom  0.505330  469
# 138                  wakaba  0.475177  423
# 115             splatroller  0.494048  336
# 84                   nzap89  0.481818  330
# 125          sputtery_clear  0.520492  244
# 11                     bold  0.523404  235
# 76                   momiji  0.509901  202
# 33                     furo  0.374359  195
# 10      barrelspinner_remix  0.489362  188
# 42       heroroller_replica  0.560440  182
# 55             hydra_custom  0.502924  171
# 134         sshooter_becchu  0.506250  160
# 29            dynamo_becchu  0.535032  157
# 56               jetsweeper  0.516556  151
# 109               sharp_neo  0.476510  149
# 135        sshooter_collabo  0.500000  136
# 62       kugelschreiber_hue  0.512605  119
# 12                   bold_7  0.601695  118
# 34                furo_deco  0.491071  112
# 106     screwslosher_becchu  0.590909  110
# 85                   ochiba  0.513761  109
# 66                  liter4k  0.504762  105
# 133                sshooter  0.419048  105
# 96            promodeler_pg  0.455446  101
# 26              dualsweeper  0.540000  100
# 50           hokusai_becchu  0.490000  100
# 74          maneuver_becchu  0.484536   97
# 65              l3reelgun_d  0.494845   97
# 87                    pablo  0.483516   91
# 82                   nzap83  0.534884   86
# 95            promodeler_mg  0.569767   86
# 98         quadhopper_black  0.581395   86
# 25         clashblaster_neo  0.476190   84
# 114    splatcharger_collabo  0.493976   83
# 13                 bold_neo  0.457831   83
# 48               hissen_hue  0.571429   77
# 32         explosher_custom  0.605263   76
# 137     variableroller_foil  0.592105   76
# 68            liter4k_scope  0.418919   74
# 63                l3reelgun  0.493151   73
# 5               bamboo14mk1  0.500000   68
# 112            splatcharger  0.417910   67
# 75         maneuver_collabo  0.507692   65
# 40      herocharger_replica  0.328125   64
# 94            prime_collabo  0.460317   63
# 3                     96gal  0.467742   62
# 23              carbon_deco  0.350000   60
# 124                sputtery  0.457627   59
# ..                      ...       ...  ...
# 18       bucketslosher_soda  0.375000   24
# 17       bucketslosher_deco  0.375000   24
# 130             squiclean_a  0.391304   23
# 128        spygadget_becchu  0.454545   22
# 97            promodeler_rg  0.636364   22
# 37              h3reelgun_d  0.333333   21
# 8             barrelspinner  0.526316   19
# 136          variableroller  0.611111   18
# 61           kugelschreiber  0.666667   18
# 101            rapid_becchu  0.555556   18
# 80              nova_becchu  0.647059   17
# 123    splatspinner_collabo  0.411765   17
# 100                   rapid  0.294118   17
# 0                     52gal  0.437500   16
# 78               nautilus79  0.500000   16
# 67           liter4k_custom  0.437500   16
# 16            bucketslosher  0.400000   15
# 122     splatspinner_becchu  0.466667   15
# 103             rapid_elite  0.357143   14
# 107        screwslosher_neo  0.571429   14
# 53        hotblaster_custom  0.285714   14
# 59         kelvin525_becchu  0.500000   14
# 7               bamboo14mk3  0.769231   13
# 19           campingshelter  0.692308   13
# 46      herospinner_replica  0.538462   13
# 58                kelvin525  0.454545   11
# 89          pablo_permanent  0.454545   11
# 99         quadhopper_white  0.454545   11
# 36         h3reelgun_cherry  0.555556    9
# 129       spygadget_sorella  0.666667    9
# 69     liter4k_scope_custom  0.500000    8
# 6               bamboo14mk2  0.571429    7
# 64         l3reelgun_becchu  0.142857    7
# 38      heroblaster_replica  0.571429    7
# 21   campingshelter_sorella  0.571429    7
# 110                soytuber  0.500000    6
# 104        rapid_elite_deco  0.500000    6
# 2                52gal_deco  0.833333    6
# 111         soytuber_custom  0.333333    6
# 24             clashblaster  0.200000    5
# 71       longblaster_custom  0.600000    5
# 39        herobrush_replica  0.400000    5
# 105            screwslosher  0.200000    5
# 45      heroslosher_replica  0.200000    5
# 90              parashelter  0.400000    5
# 35                h3reelgun  0.500000    4
# 28                   dynamo  1.000000    3
# 102              rapid_deco  0.666667    3
# 81                 nova_neo  0.333333    3
# 14             bottlegeyser  0.000000    1
#
# [139 rows x 3 columns]

# %%
df_ssp.groupby('weapon').agg({'y':'mean', 'id':'count'}).reset_index().sort_values('id', ascending=False)
# Out:
#                      weapon         y    id
# 93             prime_becchu  0.513017  1959
# 83                   nzap85  0.510283  1799
# 27       dualsweeper_custom  0.521073  1566
# 138                  wakaba  0.497072  1537
# 115             splatroller  0.504798  1042
# 84                   nzap89  0.504399  1023
# 125          sputtery_clear  0.491627   836
# 11                     bold  0.518767   746
# 10      barrelspinner_remix  0.517730   705
# 42       heroroller_replica  0.527108   664
# 33                     furo  0.466142   635
# 76                   momiji  0.515823   632
# 55             hydra_custom  0.519135   601
# 29            dynamo_becchu  0.538995   577
# 134         sshooter_becchu  0.473588   549
# 56               jetsweeper  0.510319   533
# 62       kugelschreiber_hue  0.510081   496
# 106     screwslosher_becchu  0.522777   461
# 109               sharp_neo  0.496568   437
# 135        sshooter_collabo  0.501149   435
# 85                   ochiba  0.506361   393
# 34                furo_deco  0.491049   391
# 66                  liter4k  0.493438   381
# 12                   bold_7  0.553806   381
# 133                sshooter  0.504110   365
# 26              dualsweeper  0.517045   352
# 95            promodeler_mg  0.516616   331
# 82                   nzap83  0.504532   331
# 96            promodeler_pg  0.509259   324
# 65              l3reelgun_d  0.493750   320
# 74          maneuver_becchu  0.508306   301
# 68            liter4k_scope  0.483333   300
# 114    splatcharger_collabo  0.486577   298
# 50           hokusai_becchu  0.526690   281
# 63                l3reelgun  0.492806   278
# 98         quadhopper_black  0.500000   278
# 87                    pablo  0.490909   275
# 13                 bold_neo  0.496324   272
# 32         explosher_custom  0.578358   268
# 75         maneuver_collabo  0.501887   265
# 137     variableroller_foil  0.517110   263
# 25         clashblaster_neo  0.451362   257
# 124                sputtery  0.519841   252
# 48               hissen_hue  0.518367   245
# 31                explosher  0.519824   227
# 5               bamboo14mk1  0.579909   219
# 86      octoshooter_replica  0.460094   213
# 40      herocharger_replica  0.414286   210
# 94            prime_collabo  0.502392   209
# 112            splatcharger  0.384615   208
# ..                      ...       ...   ...
# 80              nova_becchu  0.531646    79
# 43      heroshelter_replica  0.519481    77
# 52               hotblaster  0.506494    77
# 130             squiclean_a  0.306667    75
# 20      campingshelter_camo  0.472222    72
# 37              h3reelgun_d  0.430556    72
# 128        spygadget_becchu  0.514706    68
# 78               nautilus79  0.365079    63
# 101            rapid_becchu  0.507937    63
# 61           kugelschreiber  0.483333    60
# 123    splatspinner_collabo  0.456140    57
# 59         kelvin525_becchu  0.456140    57
# 136          variableroller  0.547170    53
# 0                     52gal  0.365385    52
# 8             barrelspinner  0.490196    51
# 100                   rapid  0.469388    49
# 103             rapid_elite  0.404255    47
# 7               bamboo14mk3  0.553191    47
# 16            bucketslosher  0.422222    45
# 19           campingshelter  0.533333    45
# 107        screwslosher_neo  0.590909    44
# 122     splatspinner_becchu  0.477273    44
# 53        hotblaster_custom  0.372093    43
# 67           liter4k_custom  0.428571    42
# 58                kelvin525  0.463415    41
# 64         l3reelgun_becchu  0.439024    41
# 129       spygadget_sorella  0.526316    38
# 69     liter4k_scope_custom  0.500000    38
# 90              parashelter  0.393939    33
# 46      herospinner_replica  0.500000    32
# 6               bamboo14mk2  0.516129    31
# 89          pablo_permanent  0.433333    30
# 99         quadhopper_white  0.333333    27
# 110                soytuber  0.423077    26
# 39        herobrush_replica  0.375000    24
# 36         h3reelgun_cherry  0.600000    20
# 24             clashblaster  0.421053    19
# 38      heroblaster_replica  0.526316    19
# 21   campingshelter_sorella  0.444444    18
# 104        rapid_elite_deco  0.333333    18
# 111         soytuber_custom  0.375000    16
# 71       longblaster_custom  0.333333    15
# 28                   dynamo  0.538462    13
# 35                h3reelgun  0.307692    13
# 2                52gal_deco  0.692308    13
# 45      heroslosher_replica  0.416667    12
# 105            screwslosher  0.363636    11
# 102              rapid_deco  0.400000    10
# 81                 nova_neo  0.555556     9
# 14             bottlegeyser  0.000000     1
#
# [139 rows x 3 columns]

# %%
df_area_x.query('weapon == "nzap85"').merge(
df_area_x.query('weapon == "nzap89"'), on='stage').merge(
df_area_x.query('weapon == "dualsweeper_custom"'), on='stage').sort_values('x_win_rate_x', ascending=False)
# Out:
#         stage weapon_x  x_win_rate_x  x_count_x weapon_y  x_win_rate_y  \
# 20    battera   nzap85      0.687500         16   nzap89      0.000000
# 16      manta   nzap85      0.567901         81   nzap89      0.460000
# 13  fujitsubo   nzap85      0.563830         94   nzap89      0.533333
# 4     sumeshi   nzap85      0.545455        154   nzap89      0.484848
# 5     chozame   nzap85      0.539474        152   nzap89      0.413793
# 14      kombu   nzap85      0.538462         91   nzap89      0.357143
# 6         ama   nzap85      0.532787        122   nzap89      0.416667
# 0     tachiuo   nzap85      0.526829        205   nzap89      0.312500
# 1   mutsugoro   nzap85      0.524510        204   nzap89      0.363636
# 2    hakofugu   nzap85      0.508108        185   nzap89      0.382979
# 9     anchovy   nzap85      0.504587        109   nzap89      0.652174
# 10      hokke   nzap85      0.495050        101   nzap89      0.500000
# 7       devon   nzap85      0.487179        117   nzap89      0.478261
# 11    arowana   nzap85      0.485149        101   nzap89      0.357143
# 19    mongara   nzap85      0.480000         50   nzap89      0.347826
# 15      zatou   nzap85      0.477778         90   nzap89      0.541667
# 18     ajifry   nzap85      0.477612         67   nzap89      0.533333
# 12     engawa   nzap85      0.460000        100   nzap89      0.500000
# 17    gangaze   nzap85      0.447368         76   nzap89      0.166667
# 8       bbass   nzap85      0.427273        110   nzap89      0.481481
# 3   shottsuru   nzap85      0.412121        165   nzap89      0.516129
#
#     x_count_y              weapon  x_win_rate  x_count
# 20          1  dualsweeper_custom    0.466667       15
# 16         50  dualsweeper_custom    0.348837       86
# 13         15  dualsweeper_custom    0.511628       86
# 4          33  dualsweeper_custom    0.506024      166
# 5          29  dualsweeper_custom    0.540816       98
# 14         14  dualsweeper_custom    0.533333       60
# 6          24  dualsweeper_custom    0.500000      104
# 0          48  dualsweeper_custom    0.450704      142
# 1          44  dualsweeper_custom    0.559406      202
# 2          47  dualsweeper_custom    0.593750      192
# 9          23  dualsweeper_custom    0.519231      104
# 10         32  dualsweeper_custom    0.570000      100
# 7          23  dualsweeper_custom    0.446809       94
# 11         28  dualsweeper_custom    0.556604      106
# 19         23  dualsweeper_custom    0.446154       65
# 15         24  dualsweeper_custom    0.535211       71
# 18         45  dualsweeper_custom    0.500000      102
# 12         18  dualsweeper_custom    0.528571       70
# 17          6  dualsweeper_custom    0.488372       43
# 8          27  dualsweeper_custom    0.461538       78
# 3          31  dualsweeper_custom    0.488189      127

# %%
weapon = 'nzap85'
df_area_ssp.query('weapon == @weapon').sort_values('win_rate', ascending=False)
# Out:
#           stage  weapon  win_rate  count
# 897       devon  nzap85  0.622222     90
# 1613      kombu  nzap85  0.620000     50
# 1261    gangaze  nzap85  0.616667     60
# 1385   hakofugu  nzap85  0.567568    148
# 632       bbass  nzap85  0.560000     50
# 1141  fujitsubo  nzap85  0.547368     95
# 2384    tachiuo  nzap85  0.526718    131
# 72       ajifry  nzap85  0.521277     94
# 765     chozame  nzap85  0.518868    106
# 1505      hokke  nzap85  0.507042     71
# 320     anchovy  nzap85  0.505495     91
# 197         ama  nzap85  0.500000     92
# 1990  mutsugoro  nzap85  0.494118    170
# 1857    mongara  nzap85  0.490566     53
# 2514      zatou  nzap85  0.478261     69
# 2255    sumeshi  nzap85  0.469027    113
# 1731      manta  nzap85  0.450000     60
# 2123  shottsuru  nzap85  0.438017    121
# 1019     engawa  nzap85  0.416667     36
# 531     battera  nzap85  0.388889     18
# 446     arowana  nzap85  0.382716     81

# %%
weapon = 'nzap85'
df_area_a.query('weapon == @weapon').merge(
df_area_s.query('weapon == @weapon'), on=['stage', 'weapon']).merge(
df_area_sp.query('weapon == @weapon'), on=['stage', 'weapon']).merge(
df_area_x.query('weapon == @weapon'), on=['stage', 'weapon']).sort_values('a_win_rate', ascending=False)
# Out:
#         stage  weapon  a_win_rate  a_count  s_win_rate  s_count  sp_win_rate  \
# 20    battera  nzap85    1.000000        5    0.500000       12     0.166667
# 17      hokke  nzap85    0.875000        8    0.472222       36     0.542857
# 19  fujitsubo  nzap85    0.666667        6    0.464286       28     0.582090
# 8     gangaze  nzap85    0.653846       26    0.517241       29     0.709677
# 10   hakofugu  nzap85    0.636364       22    0.675000       40     0.527778
# 16    mongara  nzap85    0.615385       13    0.538462       26     0.444444
# 5     tachiuo  nzap85    0.600000       30    0.492754       69     0.564516
# 9     chozame  nzap85    0.565217       23    0.482759       58     0.562500
# 4      engawa  nzap85    0.548387       31    0.421053       19     0.411765
# 2       bbass  nzap85    0.540541       37    0.571429       14     0.555556
# 15  shottsuru  nzap85    0.533333       15    0.375000       40     0.469136
# 0     sumeshi  nzap85    0.533333       75    0.452830       53     0.483333
# 7       zatou  nzap85    0.517241       29    0.588235       34     0.371429
# 3         ama  nzap85    0.459459       37    0.473684       57     0.542857
# 1     arowana  nzap85    0.450980       51    0.375000       32     0.387755
# 12      devon  nzap85    0.400000       20    0.688889       45     0.555556
# 11      manta  nzap85    0.380952       21    0.500000       14     0.434783
# 6   mutsugoro  nzap85    0.379310       29    0.469697       66     0.509615
# 13    anchovy  nzap85    0.333333       18    0.564103       39     0.461538
# 14     ajifry  nzap85    0.333333       18    0.600000       30     0.484375
# 18      kombu  nzap85    0.285714        7    0.714286        7     0.604651
#
#     sp_count  x_win_rate  x_count
# 20         6    0.687500       16
# 17        35    0.495050      101
# 19        67    0.563830       94
# 8         31    0.447368       76
# 10       108    0.508108      185
# 16        27    0.480000       50
# 5         62    0.526829      205
# 9         48    0.539474      152
# 4         17    0.460000      100
# 2         36    0.427273      110
# 15        81    0.412121      165
# 0         60    0.545455      154
# 7         35    0.477778       90
# 3         35    0.532787      122
# 1         49    0.485149      101
# 12        45    0.487179      117
# 11        46    0.567901       81
# 6        104    0.524510      204
# 13        52    0.504587      109
# 14        64    0.477612       67
# 18        43    0.538462       91

# %%
pd.DataFrame({
    'A' : df_a['weapon'].value_counts().head(15).index,
    'S' : df_s['weapon'].value_counts().head(15).index,
    'S+' : df_sp['weapon'].value_counts().head(15).index,
    'X' : df_x['weapon'].value_counts().head(15).index,
})
# Out:
#                       A                    S                   S+  \
# 0                nzap89               nzap85         prime_becchu
# 1          prime_becchu         prime_becchu               wakaba
# 2                nzap85   dualsweeper_custom   dualsweeper_custom
# 3    dualsweeper_custom               wakaba               nzap85
# 4           splatroller          splatroller               nzap89
# 5                wakaba               nzap89          splatroller
# 6                  bold                 bold       sputtery_clear
# 7                momiji       sputtery_clear  barrelspinner_remix
# 8        sputtery_clear                 furo   heroroller_replica
# 9                  furo  barrelspinner_remix                 bold
# 10      sshooter_becchu               momiji         hydra_custom
# 11  barrelspinner_remix           jetsweeper        dynamo_becchu
# 12           jetsweeper         hydra_custom               momiji
# 13               bold_7        dynamo_becchu                 furo
# 14        promodeler_pg      sshooter_becchu      sshooter_becchu
#
#                       X
# 0                wakaba
# 1          prime_becchu
# 2                nzap85
# 3    dualsweeper_custom
# 4    kugelschreiber_hue
# 5             l3reelgun
# 6   barrelspinner_remix
# 7      explosher_custom
# 8          hydra_custom
# 9           l3reelgun_d
# 10        dynamo_becchu
# 11          splatroller
# 12              liter4k
# 13     sshooter_collabo
# 14   splatscope_collabo

# %%
weapon = 'nzap85'
df_area_x.query('weapon == @weapon').sort_values('x_win_rate', ascending=False)
# Out:
#           stage  weapon  x_win_rate  x_count
# 590     battera  nzap85    0.687500       16
# 1898      manta  nzap85    0.567901       81
# 1234  fujitsubo  nzap85    0.563830       94
# 2434    sumeshi  nzap85    0.545455      154
# 838     chozame  nzap85    0.539474      152
# 1769      kombu  nzap85    0.538462       91
# 210         ama  nzap85    0.532787      122
# 2571    tachiuo  nzap85    0.526829      205
# 2167  mutsugoro  nzap85    0.524510      204
# 1496   hakofugu  nzap85    0.508108      185
# 345     anchovy  nzap85    0.504587      109
# 1635      hokke  nzap85    0.495050      101
# 972       devon  nzap85    0.487179      117
# 480     arowana  nzap85    0.485149      101
# 2033    mongara  nzap85    0.480000       50
# 2703      zatou  nzap85    0.477778       90
# 79       ajifry  nzap85    0.477612       67
# 1107     engawa  nzap85    0.460000      100
# 1365    gangaze  nzap85    0.447368       76
# 704       bbass  nzap85    0.427273      110
# 2300  shottsuru  nzap85    0.412121      165

# %%
stage = 'gangaze'
df_area_x.query('stage == @stage & x_count>20').sort_values('x_win_rate', ascending=False)
# Out:
#         stage               weapon  x_win_rate  x_count
# 1301  gangaze               bold_7    0.681818       22
# 1388  gangaze            sharp_neo    0.666667       21
# 1412  gangaze     sshooter_collabo    0.656250       32
# 1345  gangaze   kugelschreiber_hue    0.645833       48
# 1348  gangaze          l3reelgun_d    0.607143       28
# 1318  gangaze                 furo    0.566667       30
# 1314  gangaze        dynamo_becchu    0.555556       45
# 1299  gangaze  barrelspinner_remix    0.555556       27
# 1415  gangaze               wakaba    0.554054       74
# 1375  gangaze         prime_becchu    0.547170       53
# 1393  gangaze          splatroller    0.538462       26
# 1385  gangaze  screwslosher_becchu    0.538462       26
# 1346  gangaze            l3reelgun    0.538462       65
# 1358  gangaze               momiji    0.500000       24
# 1312  gangaze          dualsweeper    0.500000       34
# 1349  gangaze              liter4k    0.500000       32
# 1313  gangaze   dualsweeper_custom    0.488372       43
# 1398  gangaze   splatscope_collabo    0.476190       21
# 1338  gangaze         hydra_custom    0.472222       36
# 1303  gangaze    bottlegeyser_foil    0.459459       37
# 1351  gangaze        liter4k_scope    0.454545       22
# 1365  gangaze               nzap85    0.447368       76
# 1306  gangaze   bucketslosher_soda    0.439024       41
# 1403  gangaze       sputtery_clear    0.434783       23
# 1380  gangaze     quadhopper_black    0.416667       24
# 1399  gangaze         splatspinner    0.416667       24

# %%
# Out:
#           stage                weapon  x_win_rate  x_count
# 2222  mutsugoro                wakaba    0.569343      274
# 2177  mutsugoro          prime_becchu    0.511013      227
# 1551   hakofugu                wakaba    0.513274      226
# 2571    tachiuo                nzap85    0.526829      205
# 2167  mutsugoro                nzap85    0.524510      204
# 2112  mutsugoro    dualsweeper_custom    0.559406      202
# 1506   hakofugu          prime_becchu    0.562814      199
# 1441   hakofugu    dualsweeper_custom    0.593750      192
# 1496   hakofugu                nzap85    0.508108      185
# 2355  shottsuru                wakaba    0.451087      184
# 2581    tachiuo          prime_becchu    0.519337      181
# 2310  shottsuru          prime_becchu    0.514451      173
# 2380    sumeshi    dualsweeper_custom    0.506024      166
# 2300  shottsuru                nzap85    0.412121      165
# 2624    tachiuo                wakaba    0.506250      160
# 1477   hakofugu             l3reelgun    0.540881      159
# 1476   hakofugu    kugelschreiber_hue    0.515924      157
# 2434    sumeshi                nzap85    0.545455      154
# 838     chozame                nzap85    0.539474      152
# 2095  mutsugoro   barrelspinner_remix    0.466216      148
# 892     chozame                wakaba    0.506944      144
# 2147  mutsugoro             l3reelgun    0.503497      143
# 133      ajifry                wakaba    0.510490      143
# 951       devon    kugelschreiber_hue    0.521127      142
# 2516    tachiuo    dualsweeper_custom    0.450704      142
# 399     anchovy                wakaba    0.475177      141
# 2489    sumeshi                wakaba    0.539007      141
# 2444    sumeshi          prime_becchu    0.468085      141
# 89       ajifry          prime_becchu    0.546099      141
# 1950      manta                wakaba    0.535714      140
# 2146  mutsugoro    kugelschreiber_hue    0.496350      137
# 2282  shottsuru             l3reelgun    0.570370      135
# 848     chozame          prime_becchu    0.500000      134
# 1878      manta    kugelschreiber_hue    0.473684      133
# 2551    tachiuo             l3reelgun    0.553030      132
# 2414    sumeshi    kugelschreiber_hue    0.500000      130
# 2249  shottsuru    dualsweeper_custom    0.488189      127
# 2554    tachiuo               liter4k    0.524194      124
# 2117  mutsugoro      explosher_custom    0.564516      124
# 58       ajifry    kugelschreiber_hue    0.520325      123
# 714       bbass          prime_becchu    0.491803      122
# 757       bbass                wakaba    0.524590      122
# 210         ama                nzap85    0.532787      122
# 355     anchovy          prime_becchu    0.495868      121
# 2253  shottsuru      explosher_custom    0.504202      119
# 2139  mutsugoro          hydra_custom    0.495798      119
# 2521    tachiuo      explosher_custom    0.516949      118
# 2149  mutsugoro           l3reelgun_d    0.444444      117
# 972       devon                nzap85    0.487179      117
# 818     chozame             l3reelgun    0.629310      116
# ...         ...                   ...         ...      ...
# 2049    mongara      quadhopper_white    0.000000        1
# 600     battera         promodeler_rg    0.000000        1
# 1597      hokke   heroslosher_replica    0.000000        1
# 230         ama           rapid_elite    0.000000        1
# 602     battera                 rapid    0.000000        1
# 1012      devon  splatspinner_collabo    0.000000        1
# 603     battera          rapid_becchu    1.000000        1
# 443     arowana   heroslosher_replica    0.000000        1
# 604     battera      rapid_elite_deco    0.000000        1
# 1254  fujitsubo           rapid_elite    0.000000        1
# 606     battera      screwslosher_neo    1.000000        1
# 1755      kombu  liter4k_scope_custom    0.000000        1
# 801     chozame   herospinner_replica    1.000000        1
# 2047    mongara         promodeler_rg    0.000000        1
# 1154     engawa        variableroller    1.000000        1
# 1341    gangaze             kelvin525    1.000000        1
# 608     battera       soytuber_custom    1.000000        1
# 437     arowana     herobrush_replica    1.000000        1
# 2040    mongara           parashelter    0.000000        1
# 433     arowana             h3reelgun    1.000000        1
# 790     chozame             h3reelgun    0.000000        1
# 783     chozame                dynamo    1.000000        1
# 229         ama            rapid_deco    0.000000        1
# 2432    sumeshi              nova_neo    1.000000        1
# 1861      manta   heroslosher_replica    0.000000        1
# 582     battera    longblaster_custom    1.000000        1
# 585     battera      maneuver_collabo    1.000000        1
# 496     arowana      quadhopper_white    1.000000        1
# 2456    sumeshi          screwslosher    1.000000        1
# 1623      hokke    longblaster_custom    1.000000        1
# 234         ama      screwslosher_neo    1.000000        1
# 2099  mutsugoro          bottlegeyser    1.000000        1
# 2587    tachiuo      quadhopper_white    1.000000        1
# 583     battera     longblaster_necro    0.000000        1
# 584     battera       maneuver_becchu    1.000000        1
# 2450    sumeshi      quadhopper_white    0.000000        1
# 2591    tachiuo          screwslosher    0.000000        1
# 2593    tachiuo      screwslosher_neo    1.000000        1
# 1759      kombu              maneuver    1.000000        1
# 2596    tachiuo              soytuber    0.000000        1
# 991       devon            rapid_deco    1.000000        1
# 994       devon          screwslosher    0.000000        1
# 232         ama          screwslosher    0.000000        1
# 999       devon              soytuber    0.000000        1
# 591     battera                nzap89    0.000000        1
# 2246  shottsuru          clashblaster    1.000000        1
# 592     battera   octoshooter_replica    0.000000        1
# 1860      manta   heroshooter_replica    0.000000        1
# 1606      hokke                 hydra    0.000000        1
# 935       devon   herospinner_replica    0.000000        1
#
# [2751 rows x 4 columns]
